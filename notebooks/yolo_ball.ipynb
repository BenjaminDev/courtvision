# %%
from ultralytics import YOLO

# code /Users/benjamindecharmoy/Library/Application\ Support/Ultralytics/settings.yaml

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(
    data="/Users/benjamindecharmoy/projects/courtvision/datasets/ball_coco.yml",
    epochs=100,
    imgsz=640,
    # resume=True,
)
# Out:
# Ultralytics YOLOv8.0.75 🚀 Python-3.11.2 torch-2.0.1 CPU
# ...

# %%
# # model.save("yolov8n-ball.pt")
# import torch
# torch.save(model.state_dict(), "yolov8n-ball.pt")
model.info()
# Out:
# Model summary: 225 layers, 3011433 parameters, 3011417 gradients, 8.2 GFLOPs

# %%
from ultralytics import YOLO

dir(YOLO)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_is_pytorch_model',
#  '_load',
#  '_new',
#  '_reset_callbacks',
#  '_reset_ckpt_args',
#  'add_callback',
#  'benchmark',
#  'device',
#  'export',
#  'fuse',
#  'info',
#  'is_hub_model',
#  'load',
#  'names',
#  'predict',
#  'reset_weights',
#  'to',
#  'track',
#  'train',
#  'transforms',
#  'val']
